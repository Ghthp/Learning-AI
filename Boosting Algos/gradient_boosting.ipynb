# %% [markdown]
# Gradient Boosting is a technique where we use a series of weak learners to train our grad_boost_reg.
# The steps include:
#
# Step1: Use a simple grad_boost_reg (F0) e.g. mean for regressor/ log(p/1-p) for classifier
# Step2: Calculate the residual values (R1) => y - mean
# Step3: Train a decision tree on (X, R1) => gives R2
# Step4: Calculate new residual (R3) => [ y^ (pred1) = pred0 - eta. DT1(R2) ] where eta is the learning rate / change back to probability using sigmoid function for classifier
# Step5: Repeat steps 2, 3, 4.

# %% [markdown]
# # For Regression

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Generating data

X, y = make_regression(
    n_samples=1000,
    n_features=20,
    n_informative=10,
    random_state=42,
    noise=20
)

# train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Gradient Boosting model (Regressor)
from sklearn.ensemble import GradientBoostingRegressor

grad_boost_reg = GradientBoostingRegressor(  # uses DT by default
    n_estimators=100,
    learning_rate=0.1,
    max_depth=2,
    subsample=0.8,
    random_state=42
).fit(X_train, y_train)

y_pred = grad_boost_reg.predict(X_test)

# %%
print("r^2 score:", r2_score(y_test, y_pred))
# Out:
# r^2 score: 0.8973761871054992

# %% [markdown]
# # For classification

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
# Generating data

X, y = make_classification(
    n_samples=1000,
    n_features=20,
    n_informative=10,
    random_state=42,
)

# train test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Gradient Boosting model (Classifier)
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
grad_boost_class = GradientBoostingClassifier(  # uses DT by default
    n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    subsample=0.8,
    random_state=42
).fit(X_train, y_train)

y_pred = grad_boost_class.predict(X_test)

# %%
print("Accuracy score:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy score: 0.9266666666666666
